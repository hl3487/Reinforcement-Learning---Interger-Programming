# %%
import findgaps
import generate_randomip
import gurobiutils
import gymenv_v2
# import gymenv
import solverutils
import testgymenv

# %%
import tensorflow as tf
import numpy as np
import random
from gymenv_v2 import make_multiple_env
import wandb
wandb.login()
run=wandb.init(project="finalproject", entity="ieor-4575", tags=["training-easy"])
#run=wandb.init(project="finalproject", entity="ieor-4575", tags=["training-hard"])
#run=wandb.init(project="finalproject", entity="ieor-4575", tags=["test"])
# Out:
# wandb: Currently logged in as: ieor-4575 (use `wandb login --relogin` to force relogin)
# /opt/anaconda3/envs/ieor4575/lib/python3.6/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)
#                 Tracking run with wandb version 0.10.19<br/>
#                 Syncing run <strong style="color:#cdcd00">azure-valley-4467</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ieor-4575/finalproject" target="_blank">https://wandb.ai/ieor-4575/finalproject</a><br/>
#                 Run page: <a href="https://wandb.ai/ieor-4575/finalproject/runs/3j22ghxy" target="_blank">https://wandb.ai/ieor-4575/finalproject/runs/3j22ghxy</a><br/>
#                 Run data is saved locally in <code>/Users/lan/Desktop/learn2cut_gym/wandb/run-20210423_223148-3j22ghxy</code><br/><br/>

# %%
# Setup: You may generate your own instances on which you train the cutting agent.
custom_config = {
    "load_dir"        : 'instances/randomip_n60_m60',   # this is the location of the randomly generated instances (you may specify a different directory)
    "idx_list"        : list(range(20)),                # take the first 20 instances from the directory
    "timelimit"       : 50,                             # the maximum horizon length is 50
    "reward_type"     : 'obj'                           # DO NOT CHANGE reward_type
}

# Easy Setup: Use the following environment settings. We will evaluate your agent with the same easy config below:
easy_config = {
    "load_dir"        : 'instances/train_10_n60_m60',
    "idx_list"        : list(range(10)),
    "timelimit"       : 50,
    "reward_type"     : 'obj'
}

# Hard Setup: Use the following environment settings. We will evaluate your agent with the same hard config below:
hard_config = {
    "load_dir"        : 'instances/train_100_n60_m60',
    "idx_list"        : list(range(99)),
    "timelimit"       : 50,
    "reward_type"     : 'obj'
}

# %%
def calS(hg):
    h = hg[0]
    g = hg[1]
    p = tf.linalg.matmul(g,tf.transpose(h))
    p = tf.reduce_mean(p,axis=1)
    p = tf.linalg.normalize(p, ord=1)
    p = tf.nn.softmax(p[0])
    return p

# %%
def discounted_rewards(r, gamma):
    discounted_r = np.zeros_like(r)
    running_sum = 0
    for i in reversed(range(0,len(r))):
        discounted_r[i] = running_sum * gamma + r[i]
        running_sum = discounted_r[i]
    return list(discounted_r)

# %%
class Policy(object):
    
    def __init__(self, lr):

        self.model = tf.keras.models.Sequential([
                    tf.keras.layers.Input(shape=(1, 61)),
#                     tf.keras.layers.Dense(64, activation = "tanh"),
                    tf.keras.layers.LSTM(32, activation = "tanh"),
                    tf.keras.layers.Dense(10)
                ])

        self.optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
        
    
    def compute_prob(self, s):
        C = np.concatenate((s[0],np.array([s[1]]).T),axis=1)
        D = np.concatenate((s[3],np.array([s[4]]).T),axis=1)
        C = C.reshape(C.shape[0],1,C.shape[1])
        D = D.reshape(D.shape[0],1,D.shape[1])
        h = self.model(C)
        g = self.model(D)
        prob = tf.keras.layers.Lambda(calS)([h, g])
        prob = tf.cast(prob, tf.double)
        return prob.numpy()
    
    def train(self, states, actions, Qs):

        with tf.GradientTape() as tape:
            
            prob_selected = []

            for i in range(len(states)):
                C = np.concatenate((states[i][0],np.array([states[i][1]]).T),axis=1)
                D = np.concatenate((states[i][3],np.array([states[i][4]]).T),axis=1)
                C = C.reshape(C.shape[0],1,C.shape[1])
                D = D.reshape(D.shape[0],1,D.shape[1])
                h = self.model(C)
                g = self.model(D)
                prob = tf.keras.layers.Lambda(calS)([h, g])
                prob = tf.cast(prob, tf.double)

                prob_selected += [prob[actions[i]]]

            prob_selected = tf.convert_to_tensor(prob_selected)

            prob_selected += 1e-8

            loss = -tf.reduce_mean(Qs * tf.math.log(prob_selected))

            gradients = tape.gradient(loss, self.model.trainable_variables)  

            self.optimizer.apply_gradients(zip(gradients, self.model.trainable_variables))
            
        return loss.numpy()

# %%
env = make_multiple_env(**easy_config)
# Out:
# loading training instances, dir instances/train_10_n60_m60 idx 0
# loading training instances, dir instances/train_10_n60_m60 idx 1
# loading training instances, dir instances/train_10_n60_m60 idx 2
# loading training instances, dir instances/train_10_n60_m60 idx 3
# loading training instances, dir instances/train_10_n60_m60 idx 4
# loading training instances, dir instances/train_10_n60_m60 idx 5
# loading training instances, dir instances/train_10_n60_m60 idx 6
# loading training instances, dir instances/train_10_n60_m60 idx 7
# loading training instances, dir instances/train_10_n60_m60 idx 8
# loading training instances, dir instances/train_10_n60_m60 idx 9

# %%
lr = 1e-2  
numtrajs = 5 
gamma = .99
sigma = 0.02
epsilon = 0.6
iterations = 40
actor = Policy(lr) 
actor.model.build()

# %%
rrecord = []

for e in range(iterations):
    OBS = [] 
    ACTS = [] 
    ADS = []  
    VAL = []
    
    vas = actor.model.trainable_variables # set trainable_vars same for every iteration
    grashape = np.random.multivariate_normal(np.zeros(len(vas)), np.identity(len(vas)), 1).T 
    gradients = np.zeros_like(grashape)
    t = 0
    
    for num in range(numtrajs):

        s = env.reset() # get new IP
        
        done = False
        obss = []  # states
        acts = []   # actions
        rs = []
        repisode = 0
        counter = 0
        while not done:
            
            prob = actor.compute_prob(s)

            rand1 = random.random()
            if rand1>epsilon:
                action = list(np.random.randint(0, s[-1].size, 1))  
            else:
                action = [int(np.argmax(actor.compute_prob(s)))]
            
            acts += [action]
            obss += [s]
            
            s, r, done, _ = env.step(action)
            done_ = 1 if done else 0
            rs += [r]
            
            repisode += r
            print("ite",e,"traj",num,"step",counter, "action", action, "argmax", int(np.argmax(actor.compute_prob(s))), repisode)
            t += 1
            counter += 1
            
        VAL += discounted_rewards(rs, gamma)
        OBS += obss
        ACTS += acts
            
        rrecord += [repisode]
        fixedWindow=20
        movingAverage=0
        if len(rrecord) >= fixedWindow:
            movingAverage=np.mean(rrecord[len(rrecord)-fixedWindow:len(rrecord)-1])
        wandb.log({ "Training reward" : rrecord[-1], "training reward moving average" : movingAverage})


    actor.train(OBS,ACTS,np.array(VAL))
# Out:
# Using license file /Users/lan/gurobi.lic
# ite 0 traj 0 step 0 action [36] argmax 1 0.0003492276023280283
# ite 0 traj 0 step 1 action [1] argmax 1 0.0006329453194666712
# ite 0 traj 0 step 2 action [1] argmax 1 0.0009394214575877413
# ite 0 traj 0 step 3 action [58] argmax 1 0.0012637171284950455
# ite 0 traj 0 step 4 action [1] argmax 1 0.01572065219443175
# ite 0 traj 0 step 5 action [1] argmax 1 0.052210136439498456
# ite 0 traj 0 step 6 action [1] argmax 1 0.05538015366573745
# ite 0 traj 0 step 7 action [50] argmax 1 0.05561895482696855
# ite 0 traj 0 step 8 action [1] argmax 1 0.06014018590030901
# ite 0 traj 0 step 9 action [57] argmax 1 0.060874226114265184
# ite 0 traj 0 step 10 action [38] argmax 1 0.06234596262993364
# ite 0 traj 0 step 11 action [45] argmax 1 0.06649476410075295
# ite 0 traj 0 step 12 action [4] argmax 1 0.06717708095402486
# ite 0 traj 0 step 13 action [45] argmax 1 0.07662485670380192
# ite 0 traj 0 step 14 action [21] argmax 1 0.08060318980460579
# ite 0 traj 0 step 15 action [1] argmax 1 0.08070350905154555
# ite 0 traj 0 step 16 action [1] argmax 1 0.08123316197725217
# ite 0 traj 0 step 17 action [1] argmax 1 0.08378151790111588
# ite 0 traj 0 step 18 action [14] argmax 1 0.08734636155941189
# ite 0 traj 0 step 19 action [1] argmax 1 0.13522464830657555
# ite 0 traj 0 step 20 action [32] argmax 1 0.138378435109189
# ite 0 traj 0 step 21 action [1] argmax 1 0.14326191801819732
# ite 0 traj 0 step 22 action [1] argmax 1 0.143974665458245
# ite 0 traj 0 step 23 action [1] argmax 1 0.14401034080310637
# ite 0 traj 0 step 24 action [1] argmax 1 0.144046108242037
# ite 0 traj 0 step 25 action [31] argmax 1 0.14408970260637943
# ite 0 traj 0 step 26 action [1] argmax 1 0.14410946391899415
# ite 0 traj 0 step 27 action [16] argmax 1 0.14415154941752917
# ite 0 traj 0 step 28 action [1] argmax 1 0.14445136044332685
# ite 0 traj 0 step 29 action [1] argmax 1 0.14498608121084544
# ite 0 traj 0 step 30 action [28] argmax 1 0.14558920951958498
# ite 0 traj 0 step 31 action [64] argmax 1 0.1456621189317957
# ite 0 traj 0 step 32 action [1] argmax 1 0.14819177222943836
# ite 0 traj 0 step 33 action [81] argmax 1 0.14835053026718015
# ite 0 traj 0 step 34 action [61] argmax 1 0.1488779338965287
# ite 0 traj 0 step 35 action [2] argmax 1 0.14904904132708907
# ite 0 traj 0 step 36 action [73] argmax 1 0.15063360787098645
# ite 0 traj 0 step 37 action [1] argmax 1 0.15122919341411034
# ite 0 traj 0 step 38 action [90] argmax 1 0.15123602421317628
# ite 0 traj 0 step 39 action [70] argmax 1 0.15124621936820404
# ite 0 traj 0 step 40 action [87] argmax 1 0.15161916412853316
# ite 0 traj 0 step 41 action [1] argmax 1 0.15172401684912984
# ite 0 traj 0 step 42 action [65] argmax 1 0.15254358571655757
# ite 0 traj 0 step 43 action [61] argmax 1 0.1533727960345459
# ite 0 traj 0 step 44 action [1] argmax 1 0.15491497086895833
# ite 0 traj 0 step 45 action [1] argmax 1 0.15937476488761604
# ite 0 traj 0 step 46 action [1] argmax 1 0.15937542675146688
# ite 0 traj 0 step 47 action [1] argmax 1 0.15937611238950922
# ite 0 traj 0 step 48 action [90] argmax 1 0.15937734716408158
# ite 0 traj 0 step 49 action [40] argmax 1 0.15937989967460453
# ite 0 traj 1 step 0 action [8] argmax 2 0.043567147363773984
# ite 0 traj 1 step 1 action [26] argmax 1 0.0735911900917472
# ite 0 traj 1 step 2 action [22] argmax 2 0.0763018294592257
# ite 0 traj 1 step 3 action [18] argmax 1 0.08304474947271956
# ite 0 traj 1 step 4 action [1] argmax 1 0.09960210267604452
# ite 0 traj 1 step 5 action [61] argmax 0 0.12072282500025722
# ite 0 traj 1 step 6 action [0] argmax 1 0.1447225601698392
# ite 0 traj 1 step 7 action [1] argmax 1 0.1593129709749519
# ite 0 traj 1 step 8 action [48] argmax 1 0.1683980563705063
# ite 0 traj 1 step 9 action [44] argmax 1 0.1692663367593923
# ite 0 traj 1 step 10 action [1] argmax 1 0.1710617661337892
# ite 0 traj 1 step 11 action [1] argmax 1 0.17766390788756325
# ite 0 traj 1 step 12 action [1] argmax 1 0.17779860595487662
# ite 0 traj 1 step 13 action [55] argmax 1 0.17953490478794265
# ite 0 traj 1 step 14 action [26] argmax 1 0.18013323469062925
# ite 0 traj 1 step 15 action [1] argmax 1 0.18072634913642105
# ite 0 traj 1 step 16 action [52] argmax 1 0.18144525343586793
# ite 0 traj 1 step 17 action [1] argmax 1 0.18212406956013183
# ite 0 traj 1 step 18 action [71] argmax 1 0.18231040534328713
# ite 0 traj 1 step 19 action [1] argmax 1 0.1832965548148877
# ite 0 traj 1 step 20 action [1] argmax 1 0.18337414818461184
# ite 0 traj 1 step 21 action [71] argmax 1 0.183537846838135
# ite 0 traj 1 step 22 action [1] argmax 1 0.18402429955654043
# ite 0 traj 1 step 23 action [1] argmax 1 0.18452128513695243
# ite 0 traj 1 step 24 action [1] argmax 1 0.18466492119773648
# ite 0 traj 1 step 25 action [1] argmax 1 0.18475603779165795
# ite 0 traj 1 step 26 action [1] argmax 1 0.18476216434669368
# ite 0 traj 1 step 27 action [1] argmax 1 0.18488466181656804
# ite 0 traj 1 step 28 action [1] argmax 1 0.1850163419603632
# ite 0 traj 1 step 29 action [56] argmax 1 0.18501728339583678
# ite 0 traj 1 step 30 action [61] argmax 1 0.18502366173288465
# ite 0 traj 1 step 31 action [1] argmax 1 0.18520028537068356
# ite 0 traj 1 step 32 action [60] argmax 1 0.18521610803986732
# ite 0 traj 1 step 33 action [77] argmax 1 0.1853179511485905
# ite 0 traj 1 step 34 action [1] argmax 1 0.18534301983436308
# ite 0 traj 1 step 35 action [10] argmax 1 0.18539779268598977
# ite 0 traj 1 step 36 action [1] argmax 1 0.1853996106201521
# ite 0 traj 1 step 37 action [1] argmax 1 0.18540040913512712
# ite 0 traj 1 step 38 action [1] argmax 1 0.18540391105238996
# ite 0 traj 1 step 39 action [1] argmax 1 0.18540481073637238
# ite 0 traj 1 step 40 action [5] argmax 1 0.18540538572301557
# ite 0 traj 1 step 41 action [1] argmax 1 0.1854083812575027
# ite 0 traj 1 step 42 action [77] argmax 1 0.18541533849452208
# ite 0 traj 1 step 43 action [1] argmax 1 0.18541837090401714
# ite 0 traj 1 step 44 action [51] argmax 1 0.1854248583106255
# ite 0 traj 1 step 45 action [1] argmax 1 0.18547479677204137
# ite 0 traj 1 step 46 action [100] argmax 1 0.18557763932631133
# ite 0 traj 1 step 47 action [74] argmax 1 0.18575015084184088
# ite 0 traj 1 step 48 action [1] argmax 1 0.18657210917285738
# ite 0 traj 1 step 49 action [17] argmax 1 0.19241578270657556
# ite 0 traj 2 step 0 action [1] argmax 1 0.00023550753212475684
# ite 0 traj 2 step 1 action [43] argmax 1 0.008589794707859255
# ite 0 traj 2 step 2 action [1] argmax 1 0.019291089060061495
# ite 0 traj 2 step 3 action [19] argmax 1 0.020447682558369706
# ite 0 traj 2 step 4 action [1] argmax 1 0.04570529511602217
# ite 0 traj 2 step 5 action [39] argmax 1 0.04575979571109201
# ite 0 traj 2 step 6 action [48] argmax 1 0.046136644004491245
# ite 0 traj 2 step 7 action [1] argmax 1 0.04871270577041287
# ite 0 traj 2 step 8 action [1] argmax 1 0.048740127249857323
# ite 0 traj 2 step 9 action [1] argmax 1 0.04905583454728912
# ite 0 traj 2 step 10 action [16] argmax 1 0.049219249913221574
# ite 0 traj 2 step 11 action [6] argmax 1 0.05042286228035664
# ite 0 traj 2 step 12 action [1] argmax 1 0.05049164100773851
# ite 0 traj 2 step 13 action [25] argmax 1 0.05071530123314005
# ite 0 traj 2 step 14 action [1] argmax 1 0.05090193510250174
# ite 0 traj 2 step 15 action [57] argmax 1 0.0509585055719981
# ite 0 traj 2 step 16 action [1] argmax 1 0.05273764623098032
# ite 0 traj 2 step 17 action [1] argmax 1 0.05281159707556071
# ite 0 traj 2 step 18 action [15] argmax 1 0.05316033105918905
# ite 0 traj 2 step 19 action [1] argmax 1 0.054109267678086326
# ite 0 traj 2 step 20 action [1] argmax 1 0.055951204830762435
# ite 0 traj 2 step 21 action [1] argmax 1 0.05595972963692475
# ite 0 traj 2 step 22 action [63] argmax 1 0.05628073169691561
# ite 0 traj 2 step 23 action [72] argmax 1 0.05876499795795098
# ite 0 traj 2 step 24 action [21] argmax 1 0.059023553751103464
# ite 0 traj 2 step 25 action [1] argmax 1 0.06306775277425913
# ite 0 traj 2 step 26 action [29] argmax 1 0.06336019367017798
# ite 0 traj 2 step 27 action [60] argmax 1 0.0633640943356113
# ite 0 traj 2 step 28 action [1] argmax 1 0.06343206237170307
# ite 0 traj 2 step 29 action [12] argmax 1 0.06365042230663676
# ite 0 traj 2 step 30 action [1] argmax 1 0.06487716357196405
# ite 0 traj 2 step 31 action [89] argmax 1 0.06505530256754355
# ite 0 traj 2 step 32 action [0] argmax 0 0.11534908185149106
# ite 0 traj 2 step 33 action [0] argmax 0 0.11534908185149106
# ite 0 traj 2 step 34 action [87] argmax 0 0.11534908185194581
# ite 0 traj 2 step 35 action [88] argmax 0 0.11534908185240056
# ite 0 traj 2 step 36 action [0] argmax 0 0.1153490818528553
# ite 0 traj 2 step 37 action [0] argmax 0 0.1153490818528553
# ite 0 traj 2 step 38 action [0] argmax 0 0.1153490818537648
# ite 0 traj 2 step 39 action [11] argmax 0 0.11534908185421955
# ite 0 traj 2 step 40 action [71] argmax 0 0.1153490818546743
# ite 0 traj 2 step 41 action [0] argmax 0 0.11534908185512904
# ite 0 traj 2 step 42 action [0] argmax 0 0.11534908185512904
# ite 0 traj 2 step 43 action [10] argmax 0 0.11534908185512904
# ite 0 traj 2 step 44 action [0] argmax 0 0.11534908185558379
# ite 0 traj 2 step 45 action [0] argmax 0 0.11534908185603854
# ite 0 traj 2 step 46 action [0] argmax 0 0.11534908185649329
# ite 0 traj 2 step 47 action [0] argmax 0 0.11534908185694803
# ite 0 traj 2 step 48 action [42] argmax 0 0.11534908185740278
# ite 0 traj 2 step 49 action [0] argmax 0 0.11534908185785753
# ite 0 traj 3 step 0 action [55] argmax 1 0.009790643845917657
# ite 0 traj 3 step 1 action [1] argmax 1 0.019304045306853368
# ite 0 traj 3 step 2 action [60] argmax 1 0.020607358600500447
# ite 0 traj 3 step 3 action [1] argmax 1 0.024790479797957232
# ite 0 traj 3 step 4 action [1] argmax 1 0.02499770407644064
# ite 0 traj 3 step 5 action [1] argmax 1 0.025052650449197245
# ite 0 traj 3 step 6 action [34] argmax 1 0.025196618497147938
# ite 0 traj 3 step 7 action [1] argmax 1 0.025433853185177213
# ite 0 traj 3 step 8 action [1] argmax 1 0.02610539891065855
# ite 0 traj 3 step 9 action [1] argmax 1 0.029375117649351523
# ite 0 traj 3 step 10 action [1] argmax 1 0.029476642443114542
# ite 0 traj 3 step 11 action [1] argmax 1 0.03018832099814972
# ite 0 traj 3 step 12 action [17] argmax 1 0.03482415920780113
# ite 0 traj 3 step 13 action [69] argmax 1 0.035673206202773144
# ite 0 traj 3 step 14 action [10] argmax 1 0.03567503144881812
# ite 0 traj 3 step 15 action [1] argmax 1 0.035684964111396766
# ite 0 traj 3 step 16 action [13] argmax 1 0.03570420544610897
# ite 0 traj 3 step 17 action [1] argmax 1 0.035749282923234205
# ite 0 traj 3 step 18 action [1] argmax 1 0.035784810513860066
# ite 0 traj 3 step 19 action [1] argmax 1 0.03595949145596933
# ite 0 traj 3 step 20 action [63] argmax 1 0.03598920140461814
# ite 0 traj 3 step 21 action [65] argmax 1 0.03618394904151501
# ite 0 traj 3 step 22 action [46] argmax 1 0.0364330381853506
# ite 0 traj 3 step 23 action [1] argmax 1 0.0366928852156434
# ite 0 traj 3 step 24 action [12] argmax 1 0.03670074732349349
# ite 0 traj 3 step 25 action [73] argmax 1 0.03709381694943659
# ite 0 traj 3 step 26 action [36] argmax 1 0.037281163406987616
# ite 0 traj 3 step 27 action [1] argmax 1 0.037353786989569926
# ite 0 traj 3 step 28 action [64] argmax 1 0.03742671400095787
# ite 0 traj 3 step 29 action [1] argmax 1 0.037528306399963185
# ite 0 traj 3 step 30 action [1] argmax 1 0.03755265825134302
# ite 0 traj 3 step 31 action [1] argmax 1 0.03759527590500511
# ite 0 traj 3 step 32 action [1] argmax 1 0.0376257855800759
# ite 0 traj 3 step 33 action [1] argmax 1 0.03762826600745939
# ite 0 traj 3 step 34 action [1] argmax 1 0.03763396638009908
# ite 0 traj 3 step 35 action [1] argmax 1 0.03770125703817939
# ite 0 traj 3 step 36 action [50] argmax 1 0.03787351769369707
# ite 0 traj 3 step 37 action [1] argmax 1 0.03792730796749311
# ite 0 traj 3 step 38 action [1] argmax 1 0.038029168819093684
# ite 0 traj 3 step 39 action [72] argmax 1 0.03810398020436878
# ite 0 traj 3 step 40 action [22] argmax 1 0.03899588162198597
# ite 0 traj 3 step 41 action [1] argmax 1 0.039306865812022806
# ite 0 traj 3 step 42 action [1] argmax 1 0.03949794783784455
# ite 0 traj 3 step 43 action [1] argmax 1 0.039912278047268046
# ite 0 traj 3 step 44 action [30] argmax 1 0.03991804680049427
# ite 0 traj 3 step 45 action [42] argmax 1 0.03995227148197955
# ite 0 traj 3 step 46 action [60] argmax 1 0.03995614811151427
# ite 0 traj 3 step 47 action [1] argmax 1 0.04005869234765669
# ite 0 traj 3 step 48 action [1] argmax 1 0.040351020929165315
# ite 0 traj 3 step 49 action [1] argmax 1 0.04047004053472847
# ite 0 traj 4 step 0 action [1] argmax 1 0.0016034652471716981
# ite 0 traj 4 step 1 action [21] argmax 1 0.004747628216136945
# ite 0 traj 4 step 2 action [1] argmax 1 0.005411162123436952
# ite 0 traj 4 step 3 action [1] argmax 1 0.006344449145672115
# ite 0 traj 4 step 4 action [21] argmax 1 0.009249066173651954
# ite 0 traj 4 step 5 action [1] argmax 1 0.009442226516512164
# ite 0 traj 4 step 6 action [46] argmax 1 0.017121768990818964
# ite 0 traj 4 step 7 action [1] argmax 1 0.01805783036570574
# ite 0 traj 4 step 8 action [2] argmax 1 0.018448329503371497
# ite 0 traj 4 step 9 action [1] argmax 1 0.018497908282824937
# ite 0 traj 4 step 10 action [68] argmax 1 0.01859445903755841
# ite 0 traj 4 step 11 action [1] argmax 1 0.018864819443479064
# ite 0 traj 4 step 12 action [53] argmax 1 0.02266169356107639
# ite 0 traj 4 step 13 action [1] argmax 1 0.023205387574762426
# ite 0 traj 4 step 14 action [1] argmax 1 0.023322527556047135
# ite 0 traj 4 step 15 action [1] argmax 1 0.0233335588409318
# ite 0 traj 4 step 16 action [1] argmax 1 0.023471781275475223
# ite 0 traj 4 step 17 action [1] argmax 1 0.023524344059751456
# ite 0 traj 4 step 18 action [22] argmax 1 0.025531785786824912
# ite 0 traj 4 step 19 action [29] argmax 1 0.02607632221042877
# ite 0 traj 4 step 20 action [1] argmax 1 0.026135019018056482
# ite 0 traj 4 step 21 action [1] argmax 1 0.026155468685374217
# ite 0 traj 4 step 22 action [1] argmax 1 0.026390153407191974
# ite 0 traj 4 step 23 action [1] argmax 1 0.026567941886241897
# ite 0 traj 4 step 24 action [8] argmax 1 0.027283454292955867
# ite 0 traj 4 step 25 action [70] argmax 1 0.02730959738664751
# ite 0 traj 4 step 26 action [1] argmax 1 0.02733687143518182
# ite 0 traj 4 step 27 action [39] argmax 1 0.02754869779391811
# ite 0 traj 4 step 28 action [38] argmax 1 0.028106978285904916
# ite 0 traj 4 step 29 action [51] argmax 1 0.02813857735873171
# ite 0 traj 4 step 30 action [1] argmax 1 0.029059099752430484
# ite 0 traj 4 step 31 action [1] argmax 1 0.029282202731337748
# ite 0 traj 4 step 32 action [70] argmax 1 0.02935802206320659
# ite 0 traj 4 step 33 action [47] argmax 1 0.029373028083227837
# ite 0 traj 4 step 34 action [83] argmax 1 0.029932485818335408
# ite 0 traj 4 step 35 action [1] argmax 1 0.029939040064164146
# ite 0 traj 4 step 36 action [85] argmax 1 0.02994742840382969
# ite 0 traj 4 step 37 action [0] argmax 0 0.7058461509218432
# ite 0 traj 4 step 38 action [75] argmax 0 0.705846150922298
# ite 0 traj 4 step 39 action [90] argmax 0 0.705846150922298
# ite 0 traj 4 step 40 action [0] argmax 0 0.705846150922298
# ite 0 traj 4 step 41 action [0] argmax 0 0.7058461509227527
# ite 0 traj 4 step 42 action [20] argmax 0 0.7058461509232075
# ite 0 traj 4 step 43 action [63] argmax 0 0.7058461509232075
# ite 0 traj 4 step 44 action [0] argmax 0 0.7058461509232075
# ite 0 traj 4 step 45 action [0] argmax 0 0.7058461509232075
# ite 0 traj 4 step 46 action [0] argmax 0 0.7058461509236622
# ite 0 traj 4 step 47 action [93] argmax 0 0.705846150924117
# ite 0 traj 4 step 48 action [0] argmax 0 0.705846150924117
# ite 0 traj 4 step 49 action [79] argmax 0 0.705846150924117
# ite 1 traj 0 step 0 action [29] argmax 1 0.042150341945216496
# ite 1 traj 0 step 1 action [6] argmax 1 0.05389498529939374
# ite 1 traj 0 step 2 action [1] argmax 1 0.0670619833776982
# ite 1 traj 0 step 3 action [1] argmax 1 0.07465358840363479
# ite 1 traj 0 step 4 action [1] argmax 1 0.0765481003440982
# ite 1 traj 0 step 5 action [54] argmax 1 0.08101655678865427
# ite 1 traj 0 step 6 action [1] argmax 1 0.08395686062385721
# ite 1 traj 0 step 7 action [1] argmax 1 0.08399945073460913
# ite 1 traj 0 step 8 action [1] argmax 1 0.0840840015912363
# ite 1 traj 0 step 9 action [1] argmax 1 0.08455166789281066
# ite 1 traj 0 step 10 action [48] argmax 1 0.09823412798959907
# ite 1 traj 0 step 11 action [58] argmax 1 0.10574234503792468
# ite 1 traj 0 step 12 action [1] argmax 1 0.10580239332239216
# ite 1 traj 0 step 13 action [35] argmax 1 0.10776158923181356
# ite 1 traj 0 step 14 action [53] argmax 1 0.10822457567792299
# ite 1 traj 0 step 15 action [1] argmax 1 0.10964169490898712
# ite 1 traj 0 step 16 action [54] argmax 1 0.10995659463651464
# ite 1 traj 0 step 17 action [1] argmax 1 0.11020841863819442
# ite 1 traj 0 step 18 action [1] argmax 1 0.11023152771258538
# ite 1 traj 0 step 19 action [1] argmax 1 0.11028225744485098
# ite 1 traj 0 step 20 action [2] argmax 1 0.11030185903064194
# ite 1 traj 0 step 21 action [28] argmax 1 0.11045694037102294
# ite 1 traj 0 step 22 action [1] argmax 1 0.11062026386662183
# ite 1 traj 0 step 23 action [1] argmax 1 0.11070663425471139
# ite 1 traj 0 step 24 action [71] argmax 1 0.11103264286430203
# ite 1 traj 0 step 25 action [1] argmax 1 0.11104281345888012
# ite 1 traj 0 step 26 action [1] argmax 1 0.1110483865650167
# ite 1 traj 0 step 27 action [71] argmax 1 0.11107150446605374
# ite 1 traj 0 step 28 action [1] argmax 1 0.11107977948176995
# ite 1 traj 0 step 29 action [55] argmax 1 0.11109359614147252
# ite 1 traj 0 step 30 action [1] argmax 1 0.11110514617030276
# ite 1 traj 0 step 31 action [1] argmax 1 0.11111177033717468
# ite 1 traj 0 step 32 action [50] argmax 1 0.11111597956278274
# ite 1 traj 0 step 33 action [1] argmax 1 0.11111818290191877
# ite 1 traj 0 step 34 action [1] argmax 1 0.11112469957879512
# ite 1 traj 0 step 35 action [1] argmax 1 0.11112757013461305
# ite 1 traj 0 step 36 action [37] argmax 1 0.11115307953286901
# ite 1 traj 0 step 37 action [14] argmax 1 0.11116023579597822
# ite 1 traj 0 step 38 action [1] argmax 1 0.11116190544316851
# ite 1 traj 0 step 39 action [33] argmax 1 0.1111686955150617
# ite 1 traj 0 step 40 action [1] argmax 1 0.11116895730583565
# ite 1 traj 0 step 41 action [77] argmax 1 0.11116965216660901
# ite 1 traj 0 step 42 action [47] argmax 1 0.11119322671947884
# ite 1 traj 0 step 43 action [1] argmax 1 0.11119669464505932
# ite 1 traj 0 step 44 action [1] argmax 1 0.11119863680141862
# ite 1 traj 0 step 45 action [1] argmax 1 0.11120361652228894
# ite 1 traj 0 step 46 action [1] argmax 1 0.11120445818005464
# ite 1 traj 0 step 47 action [1] argmax 1 0.11120578525469682
# ite 1 traj 0 step 48 action [1] argmax 1 0.11121085343575032
# ite 1 traj 0 step 49 action [1] argmax 1 0.11122331487649717
# ite 1 traj 1 step 0 action [60] argmax 1 0.012400660326647994
# ite 1 traj 1 step 1 action [20] argmax 1 0.10735051021174513
# ite 1 traj 1 step 2 action [13] argmax 1 0.12193401717786401
# ite 1 traj 1 step 3 action [1] argmax 1 0.1286789826435779
# ite 1 traj 1 step 4 action [1] argmax 1 0.13087680804005686
# ite 1 traj 1 step 5 action [1] argmax 1 0.13295334801182435
# ite 1 traj 1 step 6 action [29] argmax 1 0.13781073343352546
# ite 1 traj 1 step 7 action [1] argmax 1 0.14104074765236874
# ite 1 traj 1 step 8 action [1] argmax 1 0.14650063827139093
# ite 1 traj 1 step 9 action [5] argmax 1 0.15070468222734235
# ite 1 traj 1 step 10 action [51] argmax 1 0.1648346819249582
# ite 1 traj 1 step 11 action [51] argmax 1 0.165354511928399
# ite 1 traj 1 step 12 action [1] argmax 1 0.17563976084352362
# ite 1 traj 1 step 13 action [1] argmax 1 0.18057742543783206
# ite 1 traj 1 step 14 action [42] argmax 1 0.18078343747674808
# ite 1 traj 1 step 15 action [29] argmax 1 0.1842993678565108
# ite 1 traj 1 step 16 action [53] argmax 1 0.18476071160785068
# ite 1 traj 1 step 17 action [1] argmax 1 0.19166791659768023
# ite 1 traj 1 step 18 action [1] argmax 1 0.1917142186782712
# ite 1 traj 1 step 19 action [1] argmax 1 0.19176130165101313
# ite 1 traj 1 step 20 action [1] argmax 1 0.1918091854395243
# ite 1 traj 1 step 21 action [27] argmax 1 0.1919112749362739
# ite 1 traj 1 step 22 action [29] argmax 1 0.19191704633158224
# ite 1 traj 1 step 23 action [12] argmax 1 0.19343043001322258
# ite 1 traj 1 step 24 action [1] argmax 1 0.19432994007297566
# ite 1 traj 1 step 25 action [9] argmax 1 0.19433227157628608
# ite 1 traj 1 step 26 action [1] argmax 1 0.19518276507596966
# ite 1 traj 1 step 27 action [1] argmax 1 0.19792038694913572
# ite 1 traj 1 step 28 action [1] argmax 1 0.19873161051691568
# ite 1 traj 1 step 29 action [1] argmax 1 0.1989404670894146
# ite 1 traj 1 step 30 action [66] argmax 1 0.1994459859545259
# ite 1 traj 1 step 31 action [1] argmax 1 0.19974944986756782
# ite 1 traj 1 step 32 action [71] argmax 1 0.20065089247214019
# ite 1 traj 1 step 33 action [1] argmax 1 0.20120389705311936
# ite 1 traj 1 step 34 action [44] argmax 1 0.2024261719120659
# ite 1 traj 1 step 35 action [1] argmax 1 0.20279123254545084
# ite 1 traj 1 step 36 action [1] argmax 1 0.203086257174391
# ite 1 traj 1 step 37 action [63] argmax 1 0.203220951185358
# ite 1 traj 1 step 38 action [34] argmax 1 0.20324797158036745
# ite 1 traj 1 step 39 action [1] argmax 1 0.20352592524909596
# ite 1 traj 1 step 40 action [1] argmax 1 0.2035330324217739
# ite 1 traj 1 step 41 action [1] argmax 1 0.2035428931176284
# ite 1 traj 1 step 42 action [1] argmax 1 0.20355749198370177
# ite 1 traj 1 step 43 action [1] argmax 1 0.20356110162788355
# ite 1 traj 1 step 44 action [1] argmax 1 0.20356825586986815
# ite 1 traj 1 step 45 action [1] argmax 1 0.2035710319159989
# ite 1 traj 1 step 46 action [16] argmax 1 0.20373308417356384
# ite 1 traj 1 step 47 action [26] argmax 1 0.20380472747251588
# ite 1 traj 1 step 48 action [1] argmax 1 0.2041794202652909
# ite 1 traj 1 step 49 action [1] argmax 1 0.20425484871589106
# ite 1 traj 2 step 0 action [1] argmax 1 0.005559518648624362
# ite 1 traj 2 step 1 action [1] argmax 1 0.01167847791521126
# ite 1 traj 2 step 2 action [9] argmax 1 0.032397193613633135
# ite 1 traj 2 step 3 action [37] argmax 1 0.035084104787074466
# ite 1 traj 2 step 4 action [1] argmax 1 0.03864854338007717
# ite 1 traj 2 step 5 action [1] argmax 1 0.0425655948702115
# ite 1 traj 2 step 6 action [1] argmax 1 0.04689030545159767
# ite 1 traj 2 step 7 action [34] argmax 1 0.04841061768502186
# ite 1 traj 2 step 8 action [1] argmax 1 0.0584874428909643
# ite 1 traj 2 step 9 action [1] argmax 1 0.07086494301711355
# ite 1 traj 2 step 10 action [54] argmax 1 0.08390762617864311
# ite 1 traj 2 step 11 action [0] argmax 0 0.8867413289726755
# ite 1 traj 2 step 12 action [0] argmax 0 0.8867413289726755
# ite 1 traj 2 step 13 action [0] argmax 0 0.8867413289726755
# ite 1 traj 2 step 14 action [63] argmax 0 0.8867413289731303
# ite 1 traj 2 step 15 action [0] argmax 0 0.8867413289740398
# ite 1 traj 2 step 16 action [0] argmax 0 0.8867413289744945
# ite 1 traj 2 step 17 action [0] argmax 0 0.8867413289749493
# ite 1 traj 2 step 18 action [21] argmax 0 0.8867413289749493
# ite 1 traj 2 step 19 action [0] argmax 0 0.886741328975404
# ite 1 traj 2 step 20 action [78] argmax 0 0.886741328975404
# ite 1 traj 2 step 21 action [33] argmax 0 0.886741328975404
# ite 1 traj 2 step 22 action [0] argmax 0 0.8867413289758588
# ite 1 traj 2 step 23 action [38] argmax 0 0.8867413289758588
# ite 1 traj 2 step 24 action [39] argmax 0 0.8867413289763135
# ite 1 traj 2 step 25 action [19] argmax 0 0.8867413289763135
# ite 1 traj 2 step 26 action [80] argmax 0 0.8867413289767683
# ite 1 traj 2 step 27 action [0] argmax 0 0.886741328977223
# ite 1 traj 2 step 28 action [18] argmax 0 0.8867413289781325
# ite 1 traj 2 step 29 action [37] argmax 0 0.8867413289794968
# ite 1 traj 2 step 30 action [0] argmax 0 0.8867413289799515
# ite 1 traj 2 step 31 action [0] argmax 0 0.8867413289799515
# ite 1 traj 2 step 32 action [0] argmax 0 0.8867413289799515
# ite 1 traj 2 step 33 action [22] argmax 0 0.8867413289799515
# ite 1 traj 2 step 34 action [0] argmax 0 0.8867413289799515
# ite 1 traj 2 step 35 action [0] argmax 0 0.8867413289799515
# ite 1 traj 2 step 36 action [73] argmax 0 0.8867413289804063
# ite 1 traj 2 step 37 action [0] argmax 0 0.886741328980861
# ite 1 traj 2 step 38 action [85] argmax 0 0.8867413289813157
# ite 1 traj 2 step 39 action [0] argmax 0 0.8867413289817705
# ite 1 traj 2 step 40 action [71] argmax 0 0.88674132898268
# ite 1 traj 2 step 41 action [10] argmax 0 0.8867413289835895
# ite 1 traj 2 step 42 action [0] argmax 0 0.8867413289835895
# ite 1 traj 2 step 43 action [0] argmax 0 0.8867413289835895
# ite 1 traj 2 step 44 action [0] argmax 0 0.8867413289840442
# ite 1 traj 2 step 45 action [15] argmax 0 0.886741328984499
# ite 1 traj 2 step 46 action [48] argmax 0 0.886741328984499
# ite 1 traj 2 step 47 action [53] argmax 0 0.8867413289849537
# ite 1 traj 2 step 48 action [33] argmax 0 0.8867413289854085
# ite 1 traj 2 step 49 action [73] argmax 0 0.8867413289858632
# ite 1 traj 3 step 0 action [12] argmax 0 0.014720996029609523
# ite 1 traj 3 step 1 action [0] argmax 0 0.1013110904154928
# ite 1 traj 3 step 2 action [51] argmax 0 0.10131109041594755
# ite 1 traj 3 step 3 action [0] argmax 0 0.10131109041594755
# ite 1 traj 3 step 4 action [16] argmax 0 0.1013110904164023
# ite 1 traj 3 step 5 action [58] argmax 0 0.10131109041685704
# ite 1 traj 3 step 6 action [35] argmax 0 0.10131109041731179
# ite 1 traj 3 step 7 action [22] argmax 0 0.10131109041822128
# ite 1 traj 3 step 8 action [26] argmax 0 0.10131109041822128
# ite 1 traj 3 step 9 action [7] argmax 0 0.10131109041913078
# ite 1 traj 3 step 10 action [0] argmax 0 0.10131109041958553
# ite 1 traj 3 step 11 action [0] argmax 0 0.10131109041958553
# ite 1 traj 3 step 12 action [55] argmax 0 0.10131109042004027
# ite 1 traj 3 step 13 action [48] argmax 0 0.10131109042049502
# ite 1 traj 3 step 14 action [0] argmax 0 0.10131109042049502
# ite 1 traj 3 step 15 action [0] argmax 0 0.10131109042140451
# ite 1 traj 3 step 16 action [0] argmax 0 0.10131109042231401
# ite 1 traj 3 step 17 action [0] argmax 0 0.10131109042276876
# ite 1 traj 3 step 18 action [35] argmax 0 0.10637035270974593
# ite 1 traj 3 step 19 action [0] argmax 0 0.10684232591620457
# ite 1 traj 3 step 20 action [0] argmax 0 0.10725467741167449
# ite 1 traj 3 step 21 action [20] argmax 0 0.10734302669925455
# ite 1 traj 3 step 22 action [0] argmax 0 0.11180241443298655
# ite 1 traj 3 step 23 action [0] argmax 0 1.1013110904236783
# ite 1 traj 3 step 24 action [0] argmax 0 1.101311090424133
# ite 1 traj 3 step 25 action [16] argmax 0 1.1013110904245877
# ite 1 traj 3 step 26 action [0] argmax 0 1.1013110904245877
# ite 1 traj 3 step 27 action [0] argmax 0 1.1013110904254972
# ite 1 traj 3 step 28 action [11] argmax 0 1.101311090425952
# ite 1 traj 3 step 29 action [0] argmax 0 1.101311090425952
# ite 1 traj 3 step 30 action [2] argmax 0 1.101311090425952
# ite 1 traj 3 step 31 action [0] argmax 0 1.101311090425952
# ite 1 traj 3 step 32 action [76] argmax 0 1.1013110904273162
# ite 1 traj 3 step 33 action [0] argmax 0 1.1013110904286805
# ite 1 traj 3 step 34 action [23] argmax 0 1.1013110904286805
# ite 1 traj 3 step 35 action [4] argmax 0 1.1013110904286805
# ite 1 traj 3 step 36 action [1] argmax 0 1.1013110904286805
# ite 1 traj 3 step 37 action [0] argmax 0 1.1013110904286805
# ite 1 traj 3 step 38 action [27] argmax 0 1.1013110904291352
# ite 1 traj 3 step 39 action [69] argmax 0 1.10131109042959
# ite 1 traj 3 step 40 action [0] argmax 0 1.1013110904300447
# ite 1 traj 3 step 41 action [0] argmax 0 1.1013110904304995
# ite 1 traj 3 step 42 action [0] argmax 0 1.1013110904304995
# ite 1 traj 3 step 43 action [73] argmax 0 1.1013110904309542
# ite 1 traj 3 step 44 action [94] argmax 0 1.1013110904309542
# ite 1 traj 3 step 45 action [47] argmax 0 1.1013110904318637
# ite 1 traj 3 step 46 action [93] argmax 0 1.1013110904323185
# ite 1 traj 3 step 47 action [0] argmax 0 1.101311090433228
# ite 1 traj 3 step 48 action [0] argmax 0 1.1013110904336827
# ite 1 traj 3 step 49 action [0] argmax 0 1.1013110904341374
# ite 1 traj 4 step 0 action [34] argmax 1 0.020567981043086547
# ite 1 traj 4 step 1 action [1] argmax 1 0.047048680384932595
# ite 1 traj 4 step 2 action [1] argmax 1 0.06720010890330741
# ite 1 traj 4 step 3 action [1] argmax 1 0.07478076322672678
# ite 1 traj 4 step 4 action [3] argmax 1 0.07796037567186431
# ite 1 traj 4 step 5 action [1] argmax 1 0.09615904406450682
# ite 1 traj 4 step 6 action [1] argmax 1 0.0980348011046317
# ite 1 traj 4 step 7 action [4] argmax 1 0.10001728252473185
# ite 1 traj 4 step 8 action [1] argmax 1 0.10512022613784211
# ite 1 traj 4 step 9 action [36] argmax 1 0.10880868032654689
# ite 1 traj 4 step 10 action [1] argmax 1 0.12271319015758309
# ite 1 traj 4 step 11 action [26] argmax 1 0.12348131921021377
# ite 1 traj 4 step 12 action [1] argmax 1 0.12409502225932556
# ite 1 traj 4 step 13 action [19] argmax 1 0.12591093513424312
# ite 1 traj 4 step 14 action [56] argmax 1 0.12618690816634626
# ite 1 traj 4 step 15 action [1] argmax 1 0.1266864525875917
# ite 1 traj 4 step 16 action [1] argmax 1 0.12677328266022414
# ite 1 traj 4 step 17 action [1] argmax 1 0.12683096147929973
# ite 1 traj 4 step 18 action [1] argmax 1 0.12692887587400037
# ite 1 traj 4 step 19 action [8] argmax 1 0.12744822525564814
# ite 1 traj 4 step 20 action [50] argmax 1 0.12749764738396152
# ite 1 traj 4 step 21 action [1] argmax 1 0.12762942010658662
# ite 1 traj 4 step 22 action [19] argmax 1 0.12812778108241218
# ite 1 traj 4 step 23 action [1] argmax 1 0.128178722176699
# ite 1 traj 4 step 24 action [1] argmax 1 0.12818499775244163
# ite 1 traj 4 step 25 action [1] argmax 1 0.12820816404087054
# ite 1 traj 4 step 26 action [72] argmax 1 0.1282864758065898
# ite 1 traj 4 step 27 action [1] argmax 1 0.12851826944074674
# ite 1 traj 4 step 28 action [1] argmax 1 0.1288946013135046
# ite 1 traj 4 step 29 action [1] argmax 1 0.12904472735249328
# ite 1 traj 4 step 30 action [1] argmax 1 0.13213302788631154
# ite 1 traj 4 step 31 action [1] argmax 1 0.13227842808328205
# ite 1 traj 4 step 32 action [1] argmax 1 0.1324743159643731
# ite 1 traj 4 step 33 action [1] argmax 1 0.13275251264440158
# ite 1 traj 4 step 34 action [1] argmax 1 0.13326460795747153
# ite 1 traj 4 step 35 action [1] argmax 1 0.13389356260722707
# ite 1 traj 4 step 36 action [1] argmax 1 0.1339030779258792
# ite 1 traj 4 step 37 action [1] argmax 1 0.13393523696413467
# ite 1 traj 4 step 38 action [1] argmax 1 0.1339650041427376
# ite 1 traj 4 step 39 action [10] argmax 1 0.1341033939852423
# ite 1 traj 4 step 40 action [37] argmax 1 0.13446177725427333
# ite 1 traj 4 step 41 action [1] argmax 1 0.13474893235024865
# ite 1 traj 4 step 42 action [1] argmax 1 0.13475830815764311
# ite 1 traj 4 step 43 action [1] argmax 1 0.13477583380995384
# ite 1 traj 4 step 44 action [51] argmax 1 0.13493693828218056
# ite 1 traj 4 step 45 action [1] argmax 1 0.1349746511016292
# ite 1 traj 4 step 46 action [68] argmax 1 0.13606259635571405
# ite 1 traj 4 step 47 action [1] argmax 1 0.13622360522072086
# ite 1 traj 4 step 48 action [36] argmax 1 0.13628083480284658
# ite 1 traj 4 step 49 action [1] argmax 1 0.13711106303344422
# ite 2 traj 0 step 0 action [0] argmax 0 0.6072478073024286
# ite 2 traj 0 step 1 action [0] argmax 0 0.6072478073031107
# ite 2 traj 0 step 2 action [29] argmax 0 0.607247807303338
# ite 2 traj 0 step 3 action [0] argmax 0 0.607247807303338
# ite 2 traj 0 step 4 action [0] argmax 0 0.6072478073037928
# ite 2 traj 0 step 5 action [0] argmax 0 0.6072478073042475
# ite 2 traj 0 step 6 action [0] argmax 0 0.6072478073044749
# ite 2 traj 0 step 7 action [0] argmax 0 0.6072478073047023
# ite 2 traj 0 step 8 action [0] argmax 0 0.6072478073047023
# ite 2 traj 0 step 9 action [0] argmax 0 0.6072478073049297
# ite 2 traj 0 step 10 action [61] argmax 0 0.6072478073053844
# ite 2 traj 0 step 11 action [0] argmax 0 0.6072478073056118
# ite 2 traj 0 step 12 action [0] argmax 0 0.6072478073056118
# ite 2 traj 0 step 13 action [8] argmax 0 0.6072478073058392
# ite 2 traj 0 step 14 action [65] argmax 0 0.6072478073060665
# ite 2 traj 0 step 15 action [0] argmax 0 0.6072478073072034
# ite 2 traj 0 step 16 action [0] argmax 0 0.607247807308795
# ite 2 traj 0 step 17 action [0] argmax 0 0.6072478073090224
# ite 2 traj 0 step 18 action [0] argmax 0 0.6072478073092498
# ite 2 traj 0 step 19 action [71] argmax 0 0.6072478073094771
# ite 2 traj 0 step 20 action [16] argmax 0 0.6072478073101593
# ite 2 traj 0 step 21 action [0] argmax 0 0.6072478073101593
# ite 2 traj 0 step 22 action [0] argmax 0 0.6072478073112961
# ite 2 traj 0 step 23 action [74] argmax 0 0.6072478073119782
# ite 2 traj 0 step 24 action [26] argmax 0 0.6072478073122056
# ite 2 traj 0 step 25 action [17] argmax 0 0.6072478073122056
# ite 2 traj 0 step 26 action [0] argmax 0 0.607247807312433
# ite 2 traj 0 step 27 action [0] argmax 0 0.6072478073133425
# ite 2 traj 0 step 28 action [0] argmax 0 0.6072478073140246
# ite 2 traj 0 step 29 action [0] argmax 0 0.607247807314252
# ite 2 traj 0 step 30 action [4] argmax 0 0.6072478073144794
# ite 2 traj 0 step 31 action [0] argmax 0 0.6072478073144794
# ite 2 traj 0 step 32 action [0] argmax 0 0.6072478073149341
# ite 2 traj 0 step 33 action [32] argmax 0 0.6072478073151615
# ite 2 traj 0 step 34 action [0] argmax 0 0.6072478073158436
# ite 2 traj 0 step 35 action [72] argmax 0 0.607247807316071
# ite 2 traj 0 step 36 action [0] argmax 0 0.6072478073165257
# ite 2 traj 0 step 37 action [63] argmax 0 0.6072478073167531
# ite 2 traj 0 step 38 action [43] argmax 0 0.6072478073172078
# ite 2 traj 0 step 39 action [0] argmax 0 0.60724780731789
# ite 2 traj 0 step 40 action [0] argmax 0 0.6072478073185721
# ite 2 traj 0 step 41 action [0] argmax 0 0.6072478073194816
# ite 2 traj 0 step 42 action [70] argmax 0 0.6072478073206184
# ite 2 traj 0 step 43 action [33] argmax 0 0.6072478073213006
# ite 2 traj 0 step 44 action [0] argmax 0 0.6072478073215279
# ite 2 traj 0 step 45 action [0] argmax 0 0.6072478073217553
# ite 2 traj 0 step 46 action [90] argmax 0 0.6072478073217553
# ite 2 traj 0 step 47 action [48] argmax 0 0.6072478073217553
# ite 2 traj 0 step 48 action [27] argmax 0 0.6072478073222101
# ite 2 traj 0 step 49 action [0] argmax 0 0.6072478073283492
# ite 2 traj 1 step 0 action [0] argmax 0 0.7082653196207502
# ite 2 traj 1 step 1 action [0] argmax 0 0.7082653196221145
# ite 2 traj 1 step 2 action [0] argmax 0 0.7082653196225692
# ite 2 traj 1 step 3 action [60] argmax 0 0.7082653196225692
# ite 2 traj 1 step 4 action [0] argmax 0 0.7082653196225692
# ite 2 traj 1 step 5 action [0] argmax 0 0.708265319623024
# ite 2 traj 1 step 6 action [0] argmax 0 0.7082653196234787
# ite 2 traj 1 step 7 action [48] argmax 0 0.7082653196239335
# ite 2 traj 1 step 8 action [0] argmax 0 0.7082653196239335
# ite 2 traj 1 step 9 action [0] argmax 0 0.7082653196243882
# ite 2 traj 1 step 10 action [0] argmax 0 0.7082653196243882
# ite 2 traj 1 step 11 action [64] argmax 0 0.708265319624843
# ite 2 traj 1 step 12 action [0] argmax 0 0.7082653196252977
# ite 2 traj 1 step 13 action [11] argmax 0 0.7082653196252977
# ite 2 traj 1 step 14 action [0] argmax 0 0.7082653196257525
# ite 2 traj 1 step 15 action [0] argmax 0 0.7082653196262072
# ite 2 traj 1 step 16 action [62] argmax 0 0.7082653196271167
# ite 2 traj 1 step 17 action [0] argmax 0 0.7082653196280262
# ite 2 traj 1 step 18 action [0] argmax 0 0.7082653196284809
# ite 2 traj 1 step 19 action [0] argmax 0 0.7082653196289357
# ite 2 traj 1 step 20 action [0] argmax 0 0.7082653196289357
# ite 2 traj 1 step 21 action [0] argmax 0 0.7082653196289357
# ite 2 traj 1 step 22 action [0] argmax 0 0.7082653196293904
# ite 2 traj 1 step 23 action [0] argmax 0 0.7082653196298452
# ite 2 traj 1 step 24 action [34] argmax 0 0.7082653196302999
# ite 2 traj 1 step 25 action [36] argmax 0 0.7082653196307547
# ite 2 traj 1 step 26 action [62] argmax 0 0.7082653196307547
# ite 2 traj 1 step 27 action [0] argmax 0 0.7082653196307547
# ite 2 traj 1 step 28 action [0] argmax 0 0.7082653196307547
# ite 2 traj 1 step 29 action [44] argmax 0 0.7082653196307547
# ite 2 traj 1 step 30 action [0] argmax 0 0.7082653196307547
# ite 2 traj 1 step 31 action [0] argmax 0 0.7082653196307547
# ite 2 traj 1 step 32 action [0] argmax 0 0.7082653196307547
# ite 2 traj 1 step 33 action [0] argmax 0 0.7082653196307547
# ite 2 traj 1 step 34 action [0] argmax 0 0.7082653196307547
# ite 2 traj 1 step 35 action [0] argmax 0 0.7082653196307547
# ite 2 traj 1 step 36 action [88] argmax 0 0.7082653196307547
# ite 2 traj 1 step 37 action [45] argmax 0 0.7082653196307547
# ite 2 traj 1 step 38 action [85] argmax 0 0.7082653196307547
# ite 2 traj 1 step 39 action [0] argmax 0 0.7082653196307547
# ite 2 traj 1 step 40 action [0] argmax 0 0.7082653196312094
# ite 2 traj 1 step 41 action [0] argmax 0 0.7082653196316642
# ite 2 traj 1 step 42 action [85] argmax 0 0.7082653196316642
# ite 2 traj 1 step 43 action [0] argmax 0 0.7082653196321189
# ite 2 traj 1 step 44 action [0] argmax 0 0.7082653196325737
# ite 2 traj 1 step 45 action [6] argmax 0 0.7082653196325737
# ite 2 traj 1 step 46 action [0] argmax 0 0.7082653196330284
# ite 2 traj 1 step 47 action [0] argmax 0 0.7082653196343927
# ite 2 traj 1 step 48 action [0] argmax 0 0.7082653196362116
# ite 2 traj 1 step 49 action [0] argmax 0 0.7082653196375759
# ite 2 traj 2 step 0 action [0] argmax 0 0.10131109041594755
# ite 2 traj 2 step 1 action [19] argmax 0 0.10131109041594755
# ite 2 traj 2 step 2 action [0] argmax 0 0.1013110904164023
# ite 2 traj 2 step 3 action [42] argmax 0 0.10131109041685704
# ite 2 traj 2 step 4 action [8] argmax 0 0.10131109041685704
# ite 2 traj 2 step 5 action [0] argmax 0 0.10131109041685704
# ite 2 traj 2 step 6 action [0] argmax 0 0.10131109041731179
# ite 2 traj 2 step 7 action [0] argmax 0 0.10131109041776654
# ite 2 traj 2 step 8 action [0] argmax 0 0.10131109041822128
# ite 2 traj 2 step 9 action [42] argmax 0 0.10131109041913078
# ite 2 traj 2 step 10 action [8] argmax 0 0.10131109041913078
# ite 2 traj 2 step 11 action [0] argmax 0 0.10131109041913078
# ite 2 traj 2 step 12 action [0] argmax 0 0.10131109041958553
# ite 2 traj 2 step 13 action [63] argmax 0 0.10131109042004027
# ite 2 traj 2 step 14 action [3] argmax 0 0.10131109042049502
# ite 2 traj 2 step 15 action [36] argmax 0 0.10131109042140451
# ite 2 traj 2 step 16 action [63] argmax 0 0.10131109042231401
# ite 2 traj 2 step 17 action [56] argmax 0 0.10131109042231401
# ite 2 traj 2 step 18 action [64] argmax 0 0.10131109042231401
# ite 2 traj 2 step 19 action [0] argmax 0 0.10131109042276876
# ite 2 traj 2 step 20 action [0] argmax 0 0.1013110904232235
# ite 2 traj 2 step 21 action [0] argmax 0 0.10131109042367825
# ite 2 traj 2 step 22 action [0] argmax 0 0.10131109042367825
# ite 2 traj 2 step 23 action [0] argmax 0 0.10225842404770447
# ite 2 traj 2 step 24 action [0] argmax 0 0.10233548967380557
# ite 2 traj 2 step 25 action [0] argmax 0 0.10242620422286564
# ite 2 traj 2 step 26 action [0] argmax 0 0.10254306225306209
# ite 2 traj 2 step 27 action [75] argmax 0 0.10254842421227295
# ite 2 traj 2 step 28 action [0] argmax 0 0.10259763592830495
# ite 2 traj 2 step 29 action [0] argmax 0 0.10264993656437582
# ite 2 traj 2 step 30 action [0] argmax 0 0.10265022441217297
# ite 2 traj 2 step 31 action [0] argmax 0 0.10265051238320666
# ite 2 traj 2 step 32 action [0] argmax 0 0.10266100129274491
# ite 2 traj 2 step 33 action [6] argmax 0 0.10270651582595747
# ite 2 traj 2 step 34 action [0] argmax 0 0.102713951068381
# ite 2 traj 2 step 35 action [33] argmax 0 0.1027291701334434
# ite 2 traj 2 step 36 action [0] argmax 0 0.1027297961795739
# ite 2 traj 2 step 37 action [0] argmax 0 0.10273455793048925
# ite 2 traj 2 step 38 action [0] argmax 0 0.10273680789896389
# ite 2 traj 2 step 39 action [0] argmax 0 0.10273906499151053
# ite 2 traj 2 step 40 action [3] argmax 0 0.10276460032991963
# ite 2 traj 2 step 41 action [0] argmax 0 0.10276462015144716
# ite 2 traj 2 step 42 action [61] argmax 0 0.10278167614433187
# ite 2 traj 2 step 43 action [0] argmax 0 0.10278233263443326
# ite 2 traj 2 step 44 action [0] argmax 0 0.10278298970979449
# ite 2 traj 2 step 45 action [0] argmax 0 0.1027837559395266
# ite 2 traj 2 step 46 action [0] argmax 0 0.10278408044132448
# ite 2 traj 2 step 47 action [31] argmax 0 0.1027919716739234
# ite 2 traj 2 step 48 action [0] argmax 0 0.10279215297259725
# ite 2 traj 2 step 49 action [0] argmax 0 0.1027923343144721
# ite 2 traj 3 step 0 action [0] argmax 0 0.11506393968329576
# ite 2 traj 3 step 1 action [0] argmax 0 0.1150639396837505
# ite 2 traj 3 step 2 action [53] argmax 0 0.11506393968488737
# ite 2 traj 3 step 3 action [0] argmax 0 0.11506393968579687
# ite 2 traj 3 step 4 action [0] argmax 0 0.11506393968579687
# ite 2 traj 3 step 5 action [0] argmax 0 0.19666967190892137
# ite 2 traj 3 step 6 action [0] argmax 0 1.1150639396860242
# ite 2 traj 3 step 7 action [0] argmax 0 1.1150639396862516
# ite 2 traj 3 step 8 action [0] argmax 0 1.1150639396862516
# ite 2 traj 3 step 9 action [1] argmax 0 1.115063939686479
# ite 2 traj 3 step 10 action [19] argmax 0 1.1150639396867064
# ite 2 traj 3 step 11 action [0] argmax 0 1.1150639396869337
# ite 2 traj 3 step 12 action [17] argmax 0 1.1150639396869337
# ite 2 traj 3 step 13 action [0] argmax 0 1.1150639396869337
# ite 2 traj 3 step 14 action [60] argmax 0 1.115063939687161
# ite 2 traj 3 step 15 action [19] argmax 0 1.115063939687161
# ite 2 traj 3 step 16 action [0] argmax 0 1.1150639396873885
# ite 2 traj 3 step 17 action [0] argmax 0 1.1150639396876159
# ite 2 traj 3 step 18 action [0] argmax 0 1.1150639396880706
# ite 2 traj 3 step 19 action [0] argmax 0 1.1150639396885254
# ite 2 traj 3 step 20 action [0] argmax 0 1.1150639396885254
# ite 2 traj 3 step 21 action [0] argmax 0 1.11506393968898
# ite 2 traj 3 step 22 action [0] argmax 0 1.1150639396892075
# ite 2 traj 3 step 23 action [0] argmax 0 1.1150639396894348
# ite 2 traj 3 step 24 action [15] argmax 0 1.1150639396896622
# ite 2 traj 3 step 25 action [0] argmax 0 1.1150639396896622
# ite 2 traj 3 step 26 action [0] argmax 0 1.115063939690117
# ite 2 traj 3 step 27 action [13] argmax 0 1.115063939690117
# ite 2 traj 3 step 28 action [68] argmax 0 1.115063939690117
# ite 2 traj 3 step 29 action [72] argmax 0 1.1150639396905717
# ite 2 traj 3 step 30 action [4] argmax 0 1.115063939690799
# ite 2 traj 3 step 31 action [81] argmax 0 1.1150639396914812
# ite 2 traj 3 step 32 action [0] argmax 0 1.1150639396921633
# ite 2 traj 3 step 33 action [0] argmax 0 1.1150639396923907
# ite 2 traj 3 step 34 action [0] argmax 0 1.115063939692618
# ite 2 traj 3 step 35 action [0] argmax 0 1.1150639396928455
# ite 2 traj 3 step 36 action [0] argmax 0 1.1150639396930728
# ite 2 traj 3 step 37 action [56] argmax 0 1.1150639396933002
# ite 2 traj 3 step 38 action [0] argmax 0 1.115063939693755
# ite 2 traj 3 step 39 action [0] argmax 0 1.1150639396958013
# ite 2 traj 3 step 40 action [0] argmax 0 1.1150639396969382
# ite 2 traj 3 step 41 action [64] argmax 0 1.1150639396996667
# ite 2 traj 3 step 42 action [0] argmax 0 1.115063939701031
# ite 2 traj 3 step 43 action [0] argmax 0 1.1150639397021678
# ite 2 traj 3 step 44 action [0] argmax 0 1.1150639397021678
# ite 2 traj 3 step 45 action [0] argmax 0 1.1150639397026225
# ite 2 traj 3 step 46 action [0] argmax 0 1.1150639397030773
# ite 2 traj 3 step 47 action [0] argmax 0 1.1150639397042141
# ite 2 traj 3 step 48 action [0] argmax 0 1.115063939705351
# ite 2 traj 3 step 49 action [0] argmax 0 1.1150639397055784
# ite 2 traj 4 step 0 action [57] argmax 0 0.002875021254112653
# ite 2 traj 4 step 1 action [59] argmax 0 0.0055443872306568664
# ite 2 traj 4 step 2 action [51] argmax 0 0.006101138943904516
# ite 2 traj 4 step 3 action [28] argmax 0 0.011569836213311646
# ite 2 traj 4 step 4 action [0] argmax 0 0.7058461509218432
# ite 2 traj 4 step 5 action [0] argmax 0 0.7058461509218432
# ite 2 traj 4 step 6 action [22] argmax 0 0.7058461509218432
# ite 2 traj 4 step 7 action [30] argmax 0 0.705846150922298
# ite 2 traj 4 step 8 action [0] argmax 0 0.705846150922298
# ite 2 traj 4 step 9 action [0] argmax 0 0.705846150922298
# ite 2 traj 4 step 10 action [4] argmax 0 0.705846150922298
# ite 2 traj 4 step 11 action [0] argmax 0 0.7058461509227527
# ite 2 traj 4 step 12 action [66] argmax 0 0.7058461509227527
# ite 2 traj 4 step 13 action [51] argmax 0 0.7058461509227527
# ite 2 traj 4 step 14 action [0] argmax 0 0.7058461509227527
# ite 2 traj 4 step 15 action [0] argmax 0 0.7058461509232075
# ite 2 traj 4 step 16 action [38] argmax 0 0.7058461509232075
# ite 2 traj 4 step 17 action [0] argmax 0 0.7058461509232075
# ite 2 traj 4 step 18 action [0] argmax 0 0.7058461509236622
# ite 2 traj 4 step 19 action [0] argmax 0 0.7058461509236622
# ite 2 traj 4 step 20 action [0] argmax 0 0.705846150924117
# ite 2 traj 4 step 21 action [0] argmax 0 0.705846150924117
# ite 2 traj 4 step 22 action [0] argmax 0 0.705846150924117
# ite 2 traj 4 step 23 action [64] argmax 0 0.7058461509245717
# ite 2 traj 4 step 24 action [31] argmax 0 0.7058461509250264
# ite 2 traj 4 step 25 action [0] argmax 0 0.7058461509250264
# ite 2 traj 4 step 26 action [0] argmax 0 0.7058461509250264
# ite 2 traj 4 step 27 action [0] argmax 0 0.7058461509250264
# ite 2 traj 4 step 28 action [43] argmax 0 0.7058461509250264
# ite 2 traj 4 step 29 action [77] argmax 0 0.7058461509254812
# ite 2 traj 4 step 30 action [0] argmax 0 0.705846150925936
# ite 2 traj 4 step 31 action [0] argmax 0 0.705846150925936
# ite 2 traj 4 step 32 action [1] argmax 0 0.705846150925936
# ite 2 traj 4 step 33 action [0] argmax 0 0.705846150925936
# ite 2 traj 4 step 34 action [0] argmax 0 0.705846150925936
# ite 2 traj 4 step 35 action [22] argmax 0 0.705846150925936
# ite 2 traj 4 step 36 action [19] argmax 0 0.705846150925936
# ite 2 traj 4 step 37 action [16] argmax 0 0.705846150925936
# ite 2 traj 4 step 38 action [52] argmax 0 0.705846150925936
# ite 2 traj 4 step 39 action [61] argmax 0 0.705846150925936
# ite 2 traj 4 step 40 action [44] argmax 0 0.705846150925936
# ite 2 traj 4 step 41 action [0] argmax 0 0.705846150925936
# ite 2 traj 4 step 42 action [0] argmax 0 0.705846150925936
# ite 2 traj 4 step 43 action [0] argmax 0 0.705846150925936
# ite 2 traj 4 step 44 action [0] argmax 0 0.705846150925936
# ite 2 traj 4 step 45 action [0] argmax 0 0.7058461509263907
# ite 2 traj 4 step 46 action [0] argmax 0 0.7058461509268454
# ite 2 traj 4 step 47 action [0] argmax 0 0.7058461509268454
# ite 2 traj 4 step 48 action [0] argmax 0 0.7058461509268454
# ite 2 traj 4 step 49 action [80] argmax 0 0.7058461509268454
# ite 3 traj 0 step 0 action [0] argmax 0 0.7022608541797126
# ite 3 traj 0 step 1 action [32] argmax 0 0.7022608541815316
# ite 3 traj 0 step 2 action [0] argmax 0 0.7022608541819864
# ite 3 traj 0 step 3 action [0] argmax 0 0.7022608541819864
# ite 3 traj 0 step 4 action [34] argmax 0 0.7022608541819864
# ite 3 traj 0 step 5 action [45] argmax 0 0.7022608541819864
# ite 3 traj 0 step 6 action [0] argmax 0 0.7022608541824411
# ite 3 traj 0 step 7 action [0] argmax 0 0.7022608541828959
# ite 3 traj 0 step 8 action [0] argmax 0 0.7022608541828959
# ite 3 traj 0 step 9 action [55] argmax 0 0.7022608541833506
# ite 3 traj 0 step 10 action [0] argmax 0 0.7022608541838053
# ite 3 traj 0 step 11 action [0] argmax 0 0.7022608541838053
# ite 3 traj 0 step 12 action [0] argmax 0 0.7022608541842601
# ite 3 traj 0 step 13 action [58] argmax 0 0.7022608541847148
# ite 3 traj 0 step 14 action [0] argmax 0 0.7022608541847148
# ite 3 traj 0 step 15 action [0] argmax 0 0.7022608541851696
# ite 3 traj 0 step 16 action [0] argmax 0 0.7022608541856243
# ite 3 traj 0 step 17 action [35] argmax 0 0.7022608541865338
# ite 3 traj 0 step 18 action [0] argmax 0 0.7022608541874433
# ite 3 traj 0 step 19 action [46] argmax 0 0.7022608541874433
# ite 3 traj 0 step 20 action [0] argmax 0 0.7022608541878981
# ite 3 traj 0 step 21 action [0] argmax 0 0.7022608541878981
# ite 3 traj 0 step 22 action [0] argmax 0 0.7022608541883528
# ite 3 traj 0 step 23 action [0] argmax 0 0.7022608541888076
# ite 3 traj 0 step 24 action [27] argmax 0 0.7022608541892623
# ite 3 traj 0 step 25 action [62] argmax 0 0.7022608541897171
# ite 3 traj 0 step 26 action [0] argmax 0 0.7022608541910813
# ite 3 traj 0 step 27 action [0] argmax 0 0.7022608541924455
# ite 3 traj 0 step 28 action [38] argmax 0 0.7022608541929003
# ite 3 traj 0 step 29 action [0] argmax 0 0.7022608541929003
# ite 3 traj 0 step 30 action [0] argmax 0 0.702260854193355
# ite 3 traj 0 step 31 action [6] argmax 0 0.7022608541938098
# ite 3 traj 0 step 32 action [0] argmax 0 0.7022608541942645
# ite 3 traj 0 step 33 action [4] argmax 0 0.7022608541947193
# ite 3 traj 0 step 34 action [0] argmax 0 0.7022608541947193
# ite 3 traj 0 step 35 action [0] argmax 0 0.7022608541947193
# ite 3 traj 0 step 36 action [84] argmax 0 0.7022608541947193
# ite 3 traj 0 step 37 action [0] argmax 0 0.702260854195174
# ite 3 traj 0 step 38 action [0] argmax 0 0.7022608541965383
# ite 3 traj 0 step 39 action [92] argmax 0 0.7022608541983573
# ...
# ite 38 traj 4 step 38 action [0] argmax 0 1.1013110904254972
# ite 38 traj 4 step 39 action [0] argmax 0 1.101311090425952
# ite 38 traj 4 step 40 action [0] argmax 0 1.101311090425952
# ite 38 traj 4 step 41 action [0] argmax 0 1.1013110904264067
# ite 38 traj 4 step 42 action [0] argmax 0 1.1013110904268615
# ite 38 traj 4 step 43 action [0] argmax 0 1.1013110904273162
# ite 38 traj 4 step 44 action [0] argmax 0 1.1013110904282257
# ite 38 traj 4 step 45 action [0] argmax 0 1.1013110904286805
# ite 38 traj 4 step 46 action [0] argmax 0 1.1013110904291352
# ite 38 traj 4 step 47 action [0] argmax 0 1.10131109042959
# ite 38 traj 4 step 48 action [0] argmax 0 1.10131109042959
# ite 38 traj 4 step 49 action [85] argmax 0 1.10131109042959
# ite 39 traj 0 step 0 action [0] argmax 0 0.7082653196207502
# ite 39 traj 0 step 1 action [40] argmax 0 0.7082653196216597
# ite 39 traj 0 step 2 action [0] argmax 0 0.7082653196239335
# ite 39 traj 0 step 3 action [15] argmax 0 0.7082653196243882
# ite 39 traj 0 step 4 action [41] argmax 0 0.708265319624843
# ite 39 traj 0 step 5 action [62] argmax 0 0.7082653196252977
# ite 39 traj 0 step 6 action [6] argmax 0 0.7082653196257525
# ite 39 traj 0 step 7 action [0] argmax 0 0.708265319626662
# ite 39 traj 0 step 8 action [50] argmax 0 0.708265319626662
# ite 39 traj 0 step 9 action [0] argmax 0 0.7082653196271167
# ite 39 traj 0 step 10 action [0] argmax 0 0.7082653196271167
# ite 39 traj 0 step 11 action [0] argmax 0 0.7082653196271167
# ite 39 traj 0 step 12 action [0] argmax 0 0.7082653196271167
# ite 39 traj 0 step 13 action [0] argmax 0 0.7082653196275714
# ite 39 traj 0 step 14 action [0] argmax 0 0.7082653196284809
# ite 39 traj 0 step 15 action [45] argmax 0 0.7082653196293904
# ite 39 traj 0 step 16 action [0] argmax 0 0.7082653196298452
# ite 39 traj 0 step 17 action [0] argmax 0 0.7082653196302999
# ite 39 traj 0 step 18 action [0] argmax 0 0.7082653196302999
# ite 39 traj 0 step 19 action [22] argmax 0 0.7082653196302999
# ite 39 traj 0 step 20 action [40] argmax 0 0.7082653196312094
# ite 39 traj 0 step 21 action [0] argmax 0 0.7082653196316642
# ite 39 traj 0 step 22 action [0] argmax 0 0.7082653196316642
# ite 39 traj 0 step 23 action [0] argmax 0 0.7082653196321189
# ite 39 traj 0 step 24 action [0] argmax 0 0.7082653196325737
# ite 39 traj 0 step 25 action [83] argmax 0 0.7082653196325737
# ite 39 traj 0 step 26 action [0] argmax 0 0.7082653196325737
# ite 39 traj 0 step 27 action [0] argmax 0 0.7082653196325737
# ite 39 traj 0 step 28 action [0] argmax 0 0.7082653196330284
# ite 39 traj 0 step 29 action [0] argmax 0 0.7082653196330284
# ite 39 traj 0 step 30 action [0] argmax 0 0.7082653196334832
# ite 39 traj 0 step 31 action [14] argmax 0 0.7082653196339379
# ite 39 traj 0 step 32 action [63] argmax 0 0.7082653196348474
# ite 39 traj 0 step 33 action [78] argmax 0 0.7082653196357569
# ite 39 traj 0 step 34 action [59] argmax 0 0.7082653196362116
# ite 39 traj 0 step 35 action [0] argmax 0 0.7082653196362116
# ite 39 traj 0 step 36 action [0] argmax 0 0.7082653196362116
# ite 39 traj 0 step 37 action [16] argmax 0 0.7082653196362116
# ite 39 traj 0 step 38 action [0] argmax 0 0.7082653196362116
# ite 39 traj 0 step 39 action [0] argmax 0 0.7082653196362116
# ite 39 traj 0 step 40 action [30] argmax 0 0.7082653196366664
# ite 39 traj 0 step 41 action [0] argmax 0 0.7082653196371211
# ite 39 traj 0 step 42 action [0] argmax 0 0.7082653196371211
# ite 39 traj 0 step 43 action [30] argmax 0 0.7082653196371211
# ite 39 traj 0 step 44 action [86] argmax 0 0.7082653196375759
# ite 39 traj 0 step 45 action [0] argmax 0 0.7082653196375759
# ite 39 traj 0 step 46 action [0] argmax 0 0.7082653196380306
# ite 39 traj 0 step 47 action [0] argmax 0 0.7082653196380306
# ite 39 traj 0 step 48 action [0] argmax 0 0.7082653196384854
# ite 39 traj 0 step 49 action [21] argmax 0 0.7082653196389401
# ite 39 traj 1 step 0 action [0] argmax 0 0.7022608541797126
# ite 39 traj 1 step 1 action [0] argmax 0 0.7022608541801674
# ite 39 traj 1 step 2 action [0] argmax 0 0.7022608541810769
# ite 39 traj 1 step 3 action [0] argmax 0 0.7022608541810769
# ite 39 traj 1 step 4 action [0] argmax 0 0.7022608541810769
# ite 39 traj 1 step 5 action [0] argmax 0 0.7022608541810769
# ite 39 traj 1 step 6 action [13] argmax 0 0.7022608541810769
# ite 39 traj 1 step 7 action [0] argmax 0 0.7022608541815316
# ite 39 traj 1 step 8 action [0] argmax 0 0.7022608541819864
# ite 39 traj 1 step 9 action [0] argmax 0 0.7022608541819864
# ite 39 traj 1 step 10 action [33] argmax 0 0.7022608541819864
# ite 39 traj 1 step 11 action [43] argmax 0 0.7022608541833506
# ite 39 traj 1 step 12 action [0] argmax 0 0.7022608541856243
# ite 39 traj 1 step 13 action [0] argmax 0 0.7022608541860791
# ite 39 traj 1 step 14 action [0] argmax 0 0.7022608541860791
# ite 39 traj 1 step 15 action [40] argmax 0 0.7022608541865338
# ite 39 traj 1 step 16 action [26] argmax 0 0.7022608541865338
# ite 39 traj 1 step 17 action [19] argmax 0 0.7022608541865338
# ite 39 traj 1 step 18 action [41] argmax 0 0.7022608541869886
# ite 39 traj 1 step 19 action [39] argmax 0 0.7022608541874433
# ite 39 traj 1 step 20 action [0] argmax 0 0.7022608541878981
# ite 39 traj 1 step 21 action [10] argmax 0 0.7022608541883528
# ite 39 traj 1 step 22 action [30] argmax 0 0.7022608541888076
# ite 39 traj 1 step 23 action [0] argmax 0 0.7022608541892623
# ite 39 traj 1 step 24 action [56] argmax 0 0.7022608541897171
# ite 39 traj 1 step 25 action [0] argmax 0 0.7022608541906266
# ite 39 traj 1 step 26 action [0] argmax 0 0.7022608541910813
# ite 39 traj 1 step 27 action [0] argmax 0 0.702260854191536
# ite 39 traj 1 step 28 action [0] argmax 0 0.7022608541919908
# ite 39 traj 1 step 29 action [0] argmax 0 0.7022608541924455
# ite 39 traj 1 step 30 action [0] argmax 0 0.7022608541929003
# ite 39 traj 1 step 31 action [0] argmax 0 0.7022608541938098
# ite 39 traj 1 step 32 action [5] argmax 0 0.7022608541942645
# ite 39 traj 1 step 33 action [0] argmax 0 0.7022608541942645
# ite 39 traj 1 step 34 action [0] argmax 0 0.7022608541942645
# ite 39 traj 1 step 35 action [0] argmax 0 0.7022608541947193
# ite 39 traj 1 step 36 action [82] argmax 0 0.702260854195174
# ite 39 traj 1 step 37 action [0] argmax 0 0.7022608541956288
# ite 39 traj 1 step 38 action [3] argmax 0 0.7022608541956288
# ite 39 traj 1 step 39 action [0] argmax 0 0.7022608541956288
# ite 39 traj 1 step 40 action [0] argmax 0 0.7022608541956288
# ite 39 traj 1 step 41 action [0] argmax 0 0.7022608541960835
# ite 39 traj 1 step 42 action [0] argmax 0 0.7022608541965383
# ite 39 traj 1 step 43 action [0] argmax 0 0.702260854196993
# ite 39 traj 1 step 44 action [66] argmax 0 0.702260854196993
# ite 39 traj 1 step 45 action [27] argmax 0 0.7022608541979025
# ite 39 traj 1 step 46 action [0] argmax 0 0.702260854198812
# ite 39 traj 1 step 47 action [0] argmax 0 0.702260854198812
# ite 39 traj 1 step 48 action [0] argmax 0 0.7022608541997215
# ite 39 traj 1 step 49 action [51] argmax 0 0.7022608541997215
# ite 39 traj 2 step 0 action [0] argmax 0 0.8867413289726755
# ite 39 traj 2 step 1 action [43] argmax 0 0.8867413289726755
# ite 39 traj 2 step 2 action [11] argmax 0 0.8867413289731303
# ite 39 traj 2 step 3 action [0] argmax 0 0.886741328973585
# ite 39 traj 2 step 4 action [0] argmax 0 0.8867413289744945
# ite 39 traj 2 step 5 action [0] argmax 0 0.8867413289763135
# ite 39 traj 2 step 6 action [0] argmax 0 0.886741328977223
# ite 39 traj 2 step 7 action [6] argmax 0 0.886741328977223
# ite 39 traj 2 step 8 action [40] argmax 0 0.886741328977223
# ite 39 traj 2 step 9 action [0] argmax 0 0.886741328977223
# ite 39 traj 2 step 10 action [61] argmax 0 0.886741328977223
# ite 39 traj 2 step 11 action [51] argmax 0 0.886741328977223
# ite 39 traj 2 step 12 action [10] argmax 0 0.8867413289776778
# ite 39 traj 2 step 13 action [0] argmax 0 0.8867413289785873
# ite 39 traj 2 step 14 action [24] argmax 0 0.886741328979042
# ite 39 traj 2 step 15 action [0] argmax 0 0.886741328979042
# ite 39 traj 2 step 16 action [0] argmax 0 0.8867413289794968
# ite 39 traj 2 step 17 action [0] argmax 0 0.8867413289794968
# ite 39 traj 2 step 18 action [0] argmax 0 0.8867413289799515
# ite 39 traj 2 step 19 action [0] argmax 0 0.8867413289799515
# ite 39 traj 2 step 20 action [0] argmax 0 0.8867413289804063
# ite 39 traj 2 step 21 action [0] argmax 0 0.886741328980861
# ite 39 traj 2 step 22 action [20] argmax 0 0.8867413289813157
# ite 39 traj 2 step 23 action [68] argmax 0 0.8867413289822252
# ite 39 traj 2 step 24 action [0] argmax 0 0.88674132898268
# ite 39 traj 2 step 25 action [0] argmax 0 0.88674132898268
# ite 39 traj 2 step 26 action [83] argmax 0 0.88674132898268
# ite 39 traj 2 step 27 action [80] argmax 0 0.88674132898268
# ite 39 traj 2 step 28 action [9] argmax 0 0.88674132898268
# ite 39 traj 2 step 29 action [0] argmax 0 0.8867413289831347
# ite 39 traj 2 step 30 action [20] argmax 0 0.8867413289840442
# ite 39 traj 2 step 31 action [0] argmax 0 0.8867413289854085
# ite 39 traj 2 step 32 action [0] argmax 0 0.886741328986318
# ite 39 traj 2 step 33 action [0] argmax 0 0.8867413289867727
# ite 39 traj 2 step 34 action [0] argmax 0 0.8867413289867727
# ite 39 traj 2 step 35 action [0] argmax 0 0.8867413289872275
# ite 39 traj 2 step 36 action [0] argmax 0 0.8867413289872275
# ite 39 traj 2 step 37 action [0] argmax 0 0.8867413289876822
# ite 39 traj 2 step 38 action [0] argmax 0 0.8867413289876822
# ite 39 traj 2 step 39 action [0] argmax 0 0.8867413289876822
# ite 39 traj 2 step 40 action [0] argmax 0 0.8867413289885917
# ite 39 traj 2 step 41 action [0] argmax 0 0.8867413289890465
# ite 39 traj 2 step 42 action [6] argmax 0 0.8867413289890465
# ite 39 traj 2 step 43 action [0] argmax 0 0.886741328989956
# ite 39 traj 2 step 44 action [0] argmax 0 0.8867413289908654
# ite 39 traj 2 step 45 action [0] argmax 0 0.8867413289913202
# ite 39 traj 2 step 46 action [81] argmax 0 0.8867413289917749
# ite 39 traj 2 step 47 action [0] argmax 0 0.8867413289917749
# ite 39 traj 2 step 48 action [35] argmax 0 0.8867413289917749
# ite 39 traj 2 step 49 action [0] argmax 0 0.8867413289917749
# ite 39 traj 3 step 0 action [0] argmax 0 0.11506393968329576
# ite 39 traj 3 step 1 action [44] argmax 0 0.11506393968352313
# ite 39 traj 3 step 2 action [0] argmax 0 0.11506393968352313
# ite 39 traj 3 step 3 action [57] argmax 0 0.1150639396837505
# ite 39 traj 3 step 4 action [0] argmax 0 0.12311684657765909
# ite 39 traj 3 step 5 action [0] argmax 0 0.1302911355305696
# ite 39 traj 3 step 6 action [0] argmax 0 1.1150639396842053
# ite 39 traj 3 step 7 action [41] argmax 0 1.1150639396844326
# ite 39 traj 3 step 8 action [61] argmax 0 1.1150639396848874
# ite 39 traj 3 step 9 action [0] argmax 0 1.1150639396853421
# ite 39 traj 3 step 10 action [0] argmax 0 1.1150639396855695
# ite 39 traj 3 step 11 action [4] argmax 0 1.1150639396857969
# ite 39 traj 3 step 12 action [21] argmax 0 1.1150639396860242
# ite 39 traj 3 step 13 action [0] argmax 0 1.1150639396860242
# ite 39 traj 3 step 14 action [0] argmax 0 1.115063939686479
# ite 39 traj 3 step 15 action [0] argmax 0 1.1150639396869337
# ite 39 traj 3 step 16 action [18] argmax 0 1.1150639396873885
# ite 39 traj 3 step 17 action [8] argmax 0 1.1150639396876159
# ite 39 traj 3 step 18 action [65] argmax 0 1.1150639396878432
# ite 39 traj 3 step 19 action [0] argmax 0 1.1150639396878432
# ite 39 traj 3 step 20 action [76] argmax 0 1.1150639396880706
# ite 39 traj 3 step 21 action [0] argmax 0 1.1150639396880706
# ite 39 traj 3 step 22 action [0] argmax 0 1.1150639396885254
# ite 39 traj 3 step 23 action [0] argmax 0 1.11506393968898
# ite 39 traj 3 step 24 action [0] argmax 0 1.11506393968898
# ite 39 traj 3 step 25 action [24] argmax 0 1.1150639396892075
# ite 39 traj 3 step 26 action [72] argmax 0 1.1150639396896622
# ite 39 traj 3 step 27 action [21] argmax 0 1.1150639396896622
# ite 39 traj 3 step 28 action [2] argmax 0 1.1150639396896622
# ite 39 traj 3 step 29 action [0] argmax 0 1.115063939690117
# ite 39 traj 3 step 30 action [0] argmax 0 1.1150639396903443
# ite 39 traj 3 step 31 action [0] argmax 0 1.115063939690799
# ite 39 traj 3 step 32 action [42] argmax 0 1.1150639396914812
# ite 39 traj 3 step 33 action [0] argmax 0 1.1150639396917086
# ite 39 traj 3 step 34 action [63] argmax 0 1.115063939691936
# ite 39 traj 3 step 35 action [13] argmax 0 1.115063939691936
# ite 39 traj 3 step 36 action [28] argmax 0 1.115063939691936
# ite 39 traj 3 step 37 action [0] argmax 0 1.1150639396921633
# ite 39 traj 3 step 38 action [71] argmax 0 1.1150639396923907
# ite 39 traj 3 step 39 action [0] argmax 0 1.1150639396928455
# ite 39 traj 3 step 40 action [18] argmax 0 1.1150639396939823
# ite 39 traj 3 step 41 action [0] argmax 0 1.1150639396948918
# ite 39 traj 3 step 42 action [83] argmax 0 1.1150639396951192
# ite 39 traj 3 step 43 action [0] argmax 0 1.1150639396953466
# ite 39 traj 3 step 44 action [32] argmax 0 1.115063939695574
# ite 39 traj 3 step 45 action [0] argmax 0 1.1150639396958013
# ite 39 traj 3 step 46 action [43] argmax 0 1.1150639396958013
# ite 39 traj 3 step 47 action [0] argmax 0 1.115063939696256
# ite 39 traj 3 step 48 action [99] argmax 0 1.1150639396967108
# ite 39 traj 3 step 49 action [66] argmax 0 1.1150639396967108
# ite 39 traj 4 step 0 action [58] argmax 0 0.008648887422396001
# ite 39 traj 4 step 1 action [36] argmax 0 0.024130674256184648
# ite 39 traj 4 step 2 action [20] argmax 0 0.030743540069579467
# ite 39 traj 4 step 3 action [3] argmax 0 0.09011841933738651
# ite 39 traj 4 step 4 action [9] argmax 0 0.10305688707239824
# ite 39 traj 4 step 5 action [0] argmax 0 0.6072478073035654
# ite 39 traj 4 step 6 action [0] argmax 0 0.6072478073049297
# ite 39 traj 4 step 7 action [6] argmax 0 0.6072478073058392
# ite 39 traj 4 step 8 action [0] argmax 0 0.6072478073058392
# ite 39 traj 4 step 9 action [0] argmax 0 0.6072478073060665
# ite 39 traj 4 step 10 action [0] argmax 0 0.6072478073062939
# ite 39 traj 4 step 11 action [0] argmax 0 0.6072478073067487
# ite 39 traj 4 step 12 action [0] argmax 0 0.6072478073076581
# ite 39 traj 4 step 13 action [5] argmax 0 0.6072478073081129
# ite 39 traj 4 step 14 action [0] argmax 0 0.6072478073081129
# ite 39 traj 4 step 15 action [0] argmax 0 0.6072478073081129
# ite 39 traj 4 step 16 action [0] argmax 0 0.6072478073081129
# ite 39 traj 4 step 17 action [0] argmax 0 0.6072478073083403
# ite 39 traj 4 step 18 action [9] argmax 0 0.6072478073083403
# ite 39 traj 4 step 19 action [33] argmax 0 0.6072478073085676
# ite 39 traj 4 step 20 action [0] argmax 0 0.6072478073090224
# ite 39 traj 4 step 21 action [77] argmax 0 0.6072478073092498
# ite 39 traj 4 step 22 action [0] argmax 0 0.6072478073094771
# ite 39 traj 4 step 23 action [0] argmax 0 0.6072478073094771
# ite 39 traj 4 step 24 action [0] argmax 0 0.6072478073097045
# ite 39 traj 4 step 25 action [54] argmax 0 0.6072478073099319
# ite 39 traj 4 step 26 action [50] argmax 0 0.6072478073101593
# ite 39 traj 4 step 27 action [0] argmax 0 0.6072478073110688
# ite 39 traj 4 step 28 action [0] argmax 0 0.6072478073115235
# ite 39 traj 4 step 29 action [0] argmax 0 0.6072478073119782
# ite 39 traj 4 step 30 action [87] argmax 0 0.6072478073119782
# ite 39 traj 4 step 31 action [0] argmax 0 0.6072478073122056
# ite 39 traj 4 step 32 action [0] argmax 0 0.607247807312433
# ite 39 traj 4 step 33 action [0] argmax 0 0.6072478073128877
# ite 39 traj 4 step 34 action [76] argmax 0 0.6072478073133425
# ite 39 traj 4 step 35 action [0] argmax 0 0.6072478073140246
# ite 39 traj 4 step 36 action [0] argmax 0 0.607247807314252
# ite 39 traj 4 step 37 action [0] argmax 0 0.6072478073144794
# ite 39 traj 4 step 38 action [0] argmax 0 0.6072478073147067
# ite 39 traj 4 step 39 action [0] argmax 0 0.6072478073149341
# ite 39 traj 4 step 40 action [51] argmax 0 0.6072478073151615
# ite 39 traj 4 step 41 action [0] argmax 0 0.6072478073151615
# ite 39 traj 4 step 42 action [0] argmax 0 0.6072478073151615
# ite 39 traj 4 step 43 action [0] argmax 0 0.6072478073156162
# ite 39 traj 4 step 44 action [0] argmax 0 0.607247807316071
# ite 39 traj 4 step 45 action [0] argmax 0 0.607247807316071
# ite 39 traj 4 step 46 action [48] argmax 0 0.6072478073172078
# ite 39 traj 4 step 47 action [0] argmax 0 0.6072478073176626
# ite 39 traj 4 step 48 action [0] argmax 0 0.6072478073176626
# ite 39 traj 4 step 49 action [0] argmax 0 0.6072478073181173

# %%
run.finish()
# Out:
# <br/>Waiting for W&B process to finish, PID 70576<br/>Program ended successfully.
# Find user logs for this run at: <code>/Users/lan/Desktop/learn2cut_gym/wandb/run-20210423_223148-3j22ghxy/logs/debug.log</code>
# Find internal logs for this run at: <code>/Users/lan/Desktop/learn2cut_gym/wandb/run-20210423_223148-3j22ghxy/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training reward</td><td>0.60725</td></tr><tr><td>training reward moving average</td><td>0.75529</td></tr><tr><td>_runtime</td><td>7380</td></tr><tr><td>_timestamp</td><td>1619195688</td></tr><tr><td>_step</td><td>199</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>Training reward</td><td>▂▁▅▅▁█▅▄█▅▄▅▁▄▆▇▅▅▁▄▅▆█▁▅▄▁██▆▄▁▄▆██▄▅▅▄</td></tr><tr><td>training reward moving average</td><td>▁▁▁▁▆▇▇▇████▇▇▇▇▇████▇█▇▇█▇▇▇▇██▇▇▇███▇█</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">azure-valley-4467</strong>: <a href="https://wandb.ai/ieor-4575/finalproject/runs/3j22ghxy" target="_blank">https://wandb.ai/ieor-4575/finalproject/runs/3j22ghxy</a><br/>
